# %% [markdown]
# <a href="https://colab.research.google.com/gist/JssanchezA/161784828538773966b31e9136ae997d/clase-1-08-032022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primner notbook
#
# $$ax^2+bx+c=0$$
#
# ## Actividad:
#
# $$\int \textit{u dv} \ = \textit{uv} \ - \int \textit{v du}$$
#
# $$ \int u \ dv \ = \ uv \ - \int v \ du $$

# %%
1+2
# Out:
# 3

# %% [markdown]
# # Clase
#
# $$ \begin{bmatrix}
# A_1 & A_2 & A_3 \\
# B_1 & B_2 & B_3 \\
# C_1 & C_2 & C_3 \\
# \end{bmatrix} $$
#
# ## Actividad:
#
# \begin{bmatrix}
# \beta _1 & \alpha _1 & \kappa _1 & \varepsilon _1 \\
# \beta _2 & \alpha _2 & \kappa _2 & \varepsilon _2 \\
# \beta _3 & \alpha _3 & \kappa _3 & \varepsilon _3 \\
# \beta _4 & \alpha _4 & \kappa _4 & \varepsilon _4 \\
# \end{bmatrix}

# %% [markdown]
# # Clase
#
# ![Python](https://th.bing.com/th/id/OIP.OWSpGf2FL9Jpee7t_AO41wHaFb?pid=ImgDet&rs=1)
#
#
# ## Actividad:
#
# ![texto del vínculo](https://content.invisioncic.com/r224567/monthly_2017_05/2000px-New-York-Yankees-Logo.svg.png.3efeeeda83d1ac6ec2ed4b71d9196eac.png)

# %% [markdown]
# \begin{array}{r l}
# Jugador & Victorias \\
# Mariano & 4 \\
# Andrés & 10 \\
# Fernando & 3
# \end{array}

# %%
import pandas as pd

# %%
pd.read_excel("/content/sample_data/Parcial.xlsx")
# Out:
#         75000                     1Ha     Unnamed: 2         Unnamed: 3  \
# 0         0.5                diametro            NaN                NaN
# 1        0.95             germinación            NaN                NaN
# 2        0,9m  distancia entre surcos            NaN                NaN
# 3         NaN                     NaN            NaN                NaN
# 4         NaN                     NaN            NaN                NaN
# 5         NaN      TIEMPOS (segundos)            NaN                NaN
# 6         NaN      Gamma baja Caracol  Velocidad m/s  Gamma intermedia
# 7         NaN                     NaN            NaN                NaN
# 8   1 cambio                    46.36       2.027997              19.91
# 9   2 cambio                    30.78       1.346457              13.23
# 10  3 cambio                    23.09       1.010061               10.2
# 11  4 cambio                    14.92       0.652668               6.68
# ...

# %% [markdown]
# ---
#
# Subir archivo excel
#
# 1. En el menu izquierdo abrir "files"
# 2. Conectar el "drive"
# 3. Buscar el archivo dentro de "mi_drive"
# 4. Copiar el path
